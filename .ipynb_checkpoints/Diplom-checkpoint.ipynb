# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

# %%
def feature_selection_RandomForest(db_full):
    """Функция отбора признаков методом случайного леса. Функция возвращает
    обученную модель"""
    
    #отбор признаков с помощью модели случайного леса

    X = db_full.select_dtypes(exclude=['object']).copy()
    if 'Flow Byts/s' in db_full.columns:
        X.drop(columns=['Flow Byts/s', 'Flow Pkts/s', 'Category_Label'],
               axis = 1, inplace=True)
    else:
        X.drop(columns=['Category_Label'],
               axis = 1, inplace=True)
    
    y = db_full['Category_Label']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    X_train.shape, y_train.shape

    clf = RandomForestClassifier()
    clf.fit(X_train, y_train)
    
    
    return clf, X

# %%
def encode_class(db):
    """Функция кодирует метки класса и возвращает датасет с новым признаком Category_Label"""
    categories = {}
    for key, value in enumerate(db['Label'].unique()):
        categories[value] = key + 1
    db['Category_Label'] = db.loc[:, 'Label'].map(categories)
    
    return db, categories

# %%
def preparing_data(db_full):
    """Функция кодирует метки целевого признака. Отбирает признаки методом случайного леса. 
    Возвращает готовые для обучения моделей данные"""    
    
    #кодирование меток
    
    db_full = encode_class(db_full)

    #исключение признаков адресации
    
    columns = db_full.columns
    if ('Flow ID' not in columns) and ('Dst Port' in columns):
        db_full.drop(columns=['Dst Port', 'Timestamp', 'Protocol'],
                axis = 1, inplace=True)
    if 'Flow ID' in columns:
        db_full.drop(columns=['Flow ID', 'Src IP', 'Src Port',
                        'Dst IP', 'Dst Port', 'Timestamp', 'Protocol'],
                axis = 1, inplace=True)
    
    #Вызов функции отбора признаков методом случайного леса
    clf, X = feature_selection_RandomForest(db_full)
    
    importnace_features = pd.Series(clf.feature_importances_, X.columns).sort_values(ascending = False)
    importnace_features = importnace_features.head(n = 8)
    

    #Переменная для вывода типов атак в каждом из файлов
    types_at = db_full['Label'].unique()
    
    return importnace_features, types_at

# %%
# %%time
db_full_1 = pd.read_csv('02-14-2018.csv')
# Out:
# CPU times: total: 4.88 s
# Wall time: 4.89 s

# %%
# %%time
db_full_2 = pd.read_csv('02-15-2018.csv')
# Out:
# CPU times: total: 5.27 s
# Wall time: 5.26 s

# %%
# %%time
db_full_3 = pd.read_csv('02-16-2018.csv')
# Out:
# CPU times: total: 4.66 s
# Wall time: 4.65 s

# %%
# %%time
db_full_4 = pd.read_csv('02-20-2018.csv')
# Out:
# CPU times: total: 1min 23s
# Wall time: 1min 33s

# %%
# %%time
db_full_5 = pd.read_csv('02-21-2018.csv')
# Out:
# CPU times: total: 5.02 s
# Wall time: 6.25 s

# %%
# %%time
db_full_6 = pd.read_csv('02-22-2018.csv')
# Out:
# CPU times: total: 5.67 s
# Wall time: 5.82 s

# %%
# %%time
db_full_7 = pd.read_csv('02-23-2018.csv')
# Out:
# CPU times: total: 5.61 s
# Wall time: 5.73 s

# %%
# %%time
db_full_8 = pd.read_csv('02-28-2018.csv')
# Out:
# CPU times: total: 3.28 s
# Wall time: 3.32 s

# %%
# %%time
db_full_9 = pd.read_csv('03-01-2018.csv')
# Out:
# CPU times: total: 1.77 s
# Wall time: 1.73 s

# %%
# %%time
db_full_10 = pd.read_csv('03-02-2018.csv')
# Out:
# CPU times: total: 5.94 s
# Wall time: 6 s

# %% [markdown]
# ## Выбор наиболее значимых признаков

# %%
# %%time
importnace_feateres_1, types_at_1 = preparing_data(db_full_1)
# Out:
# CPU times: total: 1min 28s
# Wall time: 1min 34s

# %%
importnace_feateres_1
# Out:
# Fwd Seg Size Min     0.154752
# Init Fwd Win Byts    0.100593
# Bwd Pkts/s           0.081293
# Flow Duration        0.066856
# Flow IAT Max         0.060000
# Fwd Pkts/s           0.054199
# Bwd Header Len       0.043040
# Flow IAT Mean        0.037879
# dtype: float64

# %%
# %%time
importnace_feateres_2, types_at_2 = preparing_data(db_full_2)
# Out:
# CPU times: total: 2min 7s
# Wall time: 2min 9s

# %%
# %%time
importnace_feateres_3, types_at_3 = preparing_data(db_full_3)
# Out:
# CPU times: total: 1min 50s
# Wall time: 1min 51s

# %%
# %%time
importnace_feateres_4, types_at_4 = preparing_data(db_full_4)
# Out:
# CPU times: total: 21min 13s
# Wall time: 22min 55s

# %%
importnace_feateres_4
# Out:
# Flow IAT Min        0.060996
# Fwd Pkt Len Mean    0.052987
# Fwd Seg Size Avg    0.051788
# Flow IAT Max        0.051366
# Flow Duration       0.050114
# Subflow Fwd Byts    0.044565
# Fwd Pkt Len Max     0.043730
# TotLen Fwd Pkts     0.042803
# dtype: float64

# %%
# %%time
importnace_feateres_5, types_at_5 = preparing_data(db_full_5)
# Out:
# CPU times: total: 1min 22s
# Wall time: 1min 26s

# %%
# %%time
importnace_feateres_6, types_at_6 = preparing_data(db_full_6)
# Out:
# CPU times: total: 2min 32s
# Wall time: 2min 38s

# %%
# %%time
importnace_feateres_7, types_at_7 = preparing_data(db_full_7)
# Out:
# CPU times: total: 2min 50s
# Wall time: 2min 56s

# %%
# %%time
importnace_feateres_8, types_at_8 = preparing_data(db_full_8)
# Out:
# CPU times: total: 3min 8s
# Wall time: 3min 10s

# %%
# %%time
importnace_feateres_9, types_at_9 = preparing_data(db_full_9)
# Out:
# CPU times: total: 1min 17s
# Wall time: 1min 18s

# %%
# %%time
importnace_feateres_10, types_at_10 = preparing_data(db_full_10)
# Out:
# CPU times: total: 2min 16s
# Wall time: 2min 21s

# %% [markdown]
# #### Функция pd.concat объединяет наборы данных

# %% [markdown]
# ## Таблица важности признаков для отдельных атак

# %%
im_f_2 = pd.DataFrame([importnace_feateres_1.index, importnace_feateres_2.index,
                       importnace_feateres_3.index, importnace_feateres_4.index,
                       importnace_feateres_5.index, importnace_feateres_6.index,
                       importnace_feateres_7.index, importnace_feateres_8.index,
                       importnace_feateres_9.index, importnace_feateres_10.index])
ty_a = pd.DataFrame([types_at_1, types_at_2, types_at_3, types_at_4,
                     types_at_5, types_at_6, types_at_7, types_at_8,
                     types_at_9, types_at_10])

# %%
main_features = pd.concat([im_f_2, ty_a], sort=False, axis=1)
main_features
# Out:
#                    0                  1                 2                3  \
# 0   Fwd Seg Size Min  Init Fwd Win Byts        Bwd Pkts/s    Flow Duration
# 1   Fwd Seg Size Min  Init Fwd Win Byts        Bwd Pkts/s    Flow Duration
# 2     Fwd Header Len    Fwd Pkt Len Std       Fwd IAT Tot  Fwd Pkt Len Max
# 3       Flow IAT Min   Fwd Pkt Len Mean  Fwd Seg Size Avg     Flow IAT Max
# 4       Tot Fwd Pkts   Subflow Fwd Pkts  Subflow Fwd Byts  Fwd Pkt Len Max
# 5  Init Fwd Win Byts   Subflow Fwd Byts   TotLen Fwd Pkts     ECE Flag Cnt
# 6  Init Fwd Win Byts       Flow IAT Min   Bwd Pkt Len Max    Flow Duration
# 7       Flow IAT Max      Flow Duration        Fwd Pkts/s    Flow IAT Mean
# 8         Fwd Pkts/s       Flow IAT Min     Flow IAT Mean    Flow Duration
# 9        Fwd IAT Tot        Fwd IAT Max      Fwd IAT Mean    Flow IAT Mean
#
#                   4                 5                  6                  7  \
# 0      Flow IAT Max        Fwd Pkts/s     Bwd Header Len      Flow IAT Mean
# 1      Flow IAT Max        Fwd Pkts/s     Bwd Header Len      Flow IAT Mean
# 2       Bwd IAT Min   TotLen Fwd Pkts       Fwd IAT Mean      Flow IAT Mean
# 3     Flow Duration  Subflow Fwd Byts    Fwd Pkt Len Max    TotLen Fwd Pkts
# 4  Fwd Seg Size Avg    Fwd Header Len   Fwd Pkt Len Mean    TotLen Fwd Pkts
# 5   Bwd Pkt Len Max      RST Flag Cnt        Pkt Len Max  Fwd Act Data Pkts
# 6     Flow IAT Mean       Fwd IAT Min       Fwd IAT Mean       Flow IAT Max
# 7      Flow IAT Min        Bwd Pkts/s  Init Fwd Win Byts        Fwd IAT Tot
# 8      Flow IAT Max        Bwd Pkts/s  Init Fwd Win Byts       Fwd IAT Mean
# 9        Fwd Pkts/s       Fwd IAT Min  Init Fwd Win Byts   Bwd Seg Size Avg
#
#         0                         1                      2              3
# 0  Benign            FTP-BruteForce         SSH-Bruteforce           None
# 1  Benign     DoS attacks-GoldenEye  DoS attacks-Slowloris           None
# 2  Benign  DoS attacks-SlowHTTPTest       DoS attacks-Hulk           None
# 3  Benign    DDoS attacks-LOIC-HTTP                   None           None
# 4  Benign      DDOS attack-LOIC-UDP       DDOS attack-HOIC           None
# 5  Benign          Brute Force -Web       Brute Force -XSS  SQL Injection
# 6  Benign          Brute Force -Web       Brute Force -XSS  SQL Injection
# 7  Benign             Infilteration                   None           None
# 8  Benign             Infilteration                   None           None
# 9  Benign                       Bot                   None           None

# %%
plt.figure(figsize=(24,18))
plt.subplot(4,2,1)
importnace_feateres_1\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - BruteForce FTP, SSH .1.')
plt.subplot(4,2,2)
importnace_feateres_2\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - DoS GoldenEye, Slowloris .2.')
plt.subplot(4,2,3)
importnace_feateres_3\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - DoS SlowHTTPTest, Hulk .3.')
plt.subplot(4,2,4)
importnace_feateres_4\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - DDoS LOIC-HTTP .4.')
plt.subplot(4,2,5)
importnace_feateres_5\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - DDoS LOIC-UDP .5.')
plt.subplot(4,2,6)
importnace_feateres_6\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - BruteForce Web, XSS .6.')
plt.subplot(4,2,7)
importnace_feateres_8\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - Infiltration, XSS .8.')
plt.subplot(4,2,8)
importnace_feateres_10\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для атак типа - Bot, XSS .10.')

# %% [markdown]
# ### Подготовка полного набора данных

# %%
col_cont_main_features = ['Fwd Seg Size Min', 'Bwd IAT Min', 'Fwd Pkt Len Max', 'Fwd Header Len', 
                          'Init Fwd Win Byts','Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Mean', 'Label']

# %%
# %%time
db_1 = db_full_1[col_cont_main_features]
db_2 = db_full_2[col_cont_main_features]
db_3 = db_full_3[col_cont_main_features]
db_4 = db_full_4[col_cont_main_features]
db_5 = db_full_5[col_cont_main_features]
db_6 = db_full_6[col_cont_main_features]
db_7 = db_full_7[col_cont_main_features]
db_8 = db_full_8[col_cont_main_features]
db_9 = db_full_9[col_cont_main_features]
db_10 = db_full_10[col_cont_main_features]
# Out:
# CPU times: total: 1.11 s
# Wall time: 2.09 s

# %% [markdown]
# #### Объединение наборов данных с отобранными признаками

# %%
main_db = pd.concat([db_1, db_2, db_3, db_4, db_5, db_6,
                    db_7, db_8, db_9, db_10], sort = False, axis = 0)

# %%
main_db = pd.read_csv('full_db_cut.csv')

# %%
main_db, categories = encode_class(main_db)

# %% [markdown]
# ### Оценка важности признаков готового датасета

# %%
# %%time
RandF, tr = feature_selection_RandomForest(main_db)
# Out:
# CPU times: total: 1h 18min 27s
# Wall time: 1h 18min 36s

# %%
importnace_features_main_db = pd.Series(RandF.feature_importances_, tr.columns).sort_values(ascending = False)
importnace_features_main_db\
                    .sort_values(ascending=True)\
                    .plot(kind="barh", title = 'Значимость признаков для общего датасета')
# Out:
# <AxesSubplot:title={'center':'Значимость признаков для общего датасета'}>

# %%
corr = main_db.corr()

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Кодирование меток классов и подготовка обучающих и тестовых выборок

# %%
db = main_db.sample(frac = 1, random_state=2)

# %%
train_len = int(db.shape[0] * 0.2)

# %%
db_main_1 = db[:train_len]

# %%
db_main_1.reset_index(drop=True).drop(columns='Bwd IAT Min').head()
# Out:
#    Fwd Seg Size Min  Fwd Pkt Len Max  Fwd Header Len  Init Fwd Win Byts  \
# 0                 8             77.0               8                 -1
# 1                20              0.0              40               2049
# 2                 8             49.0               8                 -1
# 3                32              0.0              64                225
# 4                20              0.0              40              32738
#
#    Flow IAT Max  Flow IAT Min  Fwd IAT Mean                   Label
# 0         550.0         550.0           0.0                  Benign
# 1    28300000.0    28300000.0    28300000.0  DDoS attacks-LOIC-HTTP
# 2         731.0         731.0           0.0                  Benign
# 3        1464.0        1464.0        1464.0        DoS attacks-Hulk
# 4        1182.0        1182.0        1182.0        DDOS attack-HOIC

# %%
y = db_main_1['Category_Label']
X = db_main_1[['Fwd Seg Size Min', 'Fwd Pkt Len Max', 'Fwd Header Len', 'Init Fwd Win Byts',
       'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Mean']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
X.describe()
# Out:
#        Fwd Seg Size Min  Fwd Pkt Len Max  Fwd Header Len  Init Fwd Win Byts  \
# count      3.246588e+06     3.246588e+06    3.246588e+06       3.246588e+06
# mean       1.799104e+01     2.008708e+02    2.513599e+02       8.790685e+03
# std        7.686313e+00     3.049211e+02    1.196623e+04       1.624413e+04
# min        0.000000e+00     0.000000e+00    0.000000e+00      -1.000000e+00
# 25%        8.000000e+00     0.000000e+00    1.600000e+01      -1.000000e+00
# 50%        2.000000e+01     4.000000e+01    4.000000e+01       9.800000e+02
# 75%        2.000000e+01     3.090000e+02    1.320000e+02       8.192000e+03
# max        4.800000e+01     6.444000e+04    1.981800e+06       6.553500e+04
#
#        Flow IAT Max  Flow IAT Min  Fwd IAT Mean
# count  3.246588e+06  3.246588e+06  3.246588e+06
# mean   6.632961e+06  1.877730e+06  3.500974e+06
# std    8.837714e+08  1.009838e+09  4.599103e+08
# min   -8.282200e+11 -9.474050e+11 -8.282200e+11
# 25%    3.940000e+02  5.000000e+00  0.000000e+00
# 50%    1.877000e+04  5.300000e+01  3.645375e+03
# 75%    1.077450e+06  9.280000e+02  3.202895e+05
# max    9.484310e+11  1.200000e+08  1.200000e+08

# %% [markdown]
# ## Метод дерева решений

# %%
DT = DecisionTreeClassifier(criterion='gini',
                            max_depth=None,
                            max_leaf_nodes=None,
                            min_samples_leaf=1)

# %%
DT = DecisionTreeClassifier()

# %%
# %%time
DT.fit(X_train, y_train)
# Out:
# CPU times: total: 31 s
# Wall time: 31 s
# DecisionTreeClassifier()

# %%
# %%time
DT_predict = DT.predict(X_test)
# Out:
# CPU times: total: 219 ms
# Wall time: 229 ms

# %%
print( 'Accuracy score:', accuracy_score(y_test, DT_predict))
# Out:
# Accuracy score: 0.9800267357442732

# %%
cm = confusion_matrix(DT_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'cividis')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %% [markdown]
# ## Метод Случайного леса

# %%
RF = RandomForestClassifier(criterion='entropy',
                            max_depth=None,
                            max_features=7,
                            min_samples_split=10,
                            n_estimators=100)

# %%
# %%time
RF.fit(X_train, y_train)
# Out:
# CPU times: total: 39min 28s
# Wall time: 39min 32s
# RandomForestClassifier(criterion='entropy', max_features=7,
#                        min_samples_split=10)

# %%
# %%time
RF_predict = RF.predict(X_test)
# Out:
# CPU times: total: 16.8 s
# Wall time: 16.8 s

# %%
print( 'Accuracy score:', accuracy_score(y_test, RF_predict))
# Out:
# Accuracy score: 0.9840663588565233

# %%
print( 'Accuracy score:', accuracy_score(y_test, RF_predict))
# Out:
# Accuracy score: 0.9840663588565233

# %%
cm = confusion_matrix(RF_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'Greens')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %% [markdown]
# #### Масштабирование призанков на основе  Z-оценки

# %%
standart_scaler = StandardScaler()

# %%
X_stand = pd.DataFrame(data = standart_scaler.fit_transform(X), columns = X.columns)

# %%
X_stand.describe()
# Out:
#        Fwd Seg Size Min  Fwd Pkt Len Max  Fwd Header Len  Init Fwd Win Byts  \
# count      3.246588e+06     3.246588e+06    3.246588e+06       3.246588e+06
# mean      -2.187292e-16    -3.091811e-17   -1.085537e-18       5.392012e-17
# std        1.000000e+00     1.000000e+00    1.000000e+00       1.000000e+00
# min       -2.340660e+00    -6.587632e-01   -2.100577e-02      -5.412224e-01
# 25%       -1.299849e+00    -6.587632e-01   -1.966867e-02      -5.412224e-01
# 50%        2.613680e-01    -5.275817e-01   -1.766303e-02      -4.808313e-01
# 75%        2.613680e-01     3.546138e-01   -9.974726e-03      -3.685547e-02
# max        3.904207e+00     2.106746e+02    1.655951e+02       3.493220e+00
#
#        Flow IAT Max  Flow IAT Min  Fwd IAT Mean
# count  3.246588e+06  3.246588e+06  3.246588e+06
# mean  -3.732902e-19 -3.706912e-19 -4.109065e-19
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.371504e+02 -9.381777e+02 -1.800837e+03
# 25%   -7.504846e-03 -1.859433e-03 -7.612299e-03
# 50%   -7.484053e-03 -1.859385e-03 -7.604372e-03
# 75%   -6.286141e-03 -1.858519e-03 -6.915881e-03
# max    1.073156e+03  1.169716e-01  2.533082e-01

# %%
X_train_stand, X_test_stand, y_train, y_test = train_test_split(X_stand,
                                                                y,
                                                                test_size=0.2,
                                                                random_state=1,
                                                                stratify=y)

# %% [markdown]
# ## Метод K ближайших соседей

# %%
KNN = KNeighborsClassifier(n_neighbors=6)

# %%
# %%time
KNN.fit(X_train_stand, y_train)
# Out:
# CPU times: total: 12 s
# Wall time: 12 s
# KNeighborsClassifier(n_neighbors=6)

# %%
# %%time
KNN_predict = KNN.predict(X_test_stand)
# Out:
# CPU times: total: 4min 17s
# Wall time: 4min 17s

# %%
print( 'Accuracy score:', accuracy_score(y_test, KNN_predict))
# Out:
# Accuracy score: 0.982446197394805

# %%
print( 'Accuracy score:', accuracy_score(y_test, KNN_predict))
# Out:
# Accuracy score: 0.982446197394805

# %%
cm = confusion_matrix(KNN_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'Greens')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %% [markdown]
# ## Метод Логистической регрессии

# %%
LR = LogisticRegression(C = 1.0, solver='liblinear', max_iter=100)

# %%
# %%time
LR.fit(X_train_stand, y_train)
# Out:
# CPU times: total: 4min 45s
# Wall time: 4min 45s
# c:\users\egord\appdata\local\programs\python\python39\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LogisticRegression(solver='liblinear')

# %%
# %%time
LR_predict = LR.predict(X_test_stand)
# Out:
# CPU times: total: 188 ms
# Wall time: 73.8 ms

# %%
print( 'Accuracy score:', accuracy_score(y_test, LR_predict))
# Out:
# Accuracy score: 0.8668125633356846

# %%
print( 'Accuracy score:', accuracy_score(y_test, LR_predict))
# Out:
# Accuracy score: 0.8668125633356846

# %%
cm = confusion_matrix(LR_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'cividis')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %% [markdown]
# ## Метод Байеса

# %%
NB = GaussianNB()

# %%
scaler = MinMaxScaler()
X_train_MinMax = scaler.fit_transform(X_train)
X_test_MinMax  = scaler.transform(X_test)

# %%
# %%time
NB.fit(X_train_stand, y_train)
# Out:
# CPU times: total: 562 ms
# Wall time: 564 ms
# GaussianNB()

# %%
# %%time
NB_predict = NB.predict(X_test)
# Out:
# CPU times: total: 656 ms
# Wall time: 650 ms

# %%
accuracy_score(NB_predict, y_test)
# Out:
# 0.8298122029575647

# %%
cm = confusion_matrix(NB_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'Reds')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %% [markdown]
# ## Метод AdaBoost

# %%
AB = AdaBoostClassifier(n_estimators=100)

# %%
# %%time
AB.fit(X_train, y_train)
# Out:
# CPU times: total: 5min 43s
# Wall time: 5min 44s
# AdaBoostClassifier(n_estimators=100)

# %%
# %%time
AB_predict = AB.predict(X_test)
# Out:
# CPU times: total: 22.6 s
# Wall time: 22.6 s

# %%
accuracy_score(AB_predict, y_test)
# Out:
# 0.8306469249273853

# %%
cm = confusion_matrix(AB_predict,
                      y_test,
                      normalize='true')

# %%
plt.figure(figsize=(13,9))
hm = sns.heatmap(cm,
            annot=True,
            xticklabels=categories.keys(),
            yticklabels=categories.keys(),
            cmap = 'Reds')
hm.set_xlabel('Predicted label')
hm.set_ylabel('True label')
# Out:
# Text(95.99999999999999, 0.5, 'True label')

# %%
DT_predict = DT.predict(X_test)

# %%
RF_predict = RF.predict(X_test)

# %%
KNN_predict = KNN.predict(X_test_stand)

# %%
LR_predict = LR.predict(X_test_stand)

# %%
NB_predict = NB.predict(X_test)

# %%
AB_predict = AB.predict(X_test)

# %%
predict = []

# %%
predict.append(('DecisionTreeClassifier', DT.predict(X_test)))

# %%
predict.append(('RandomForestClassifier', RF.predict(X_test))

# %%
predict.append(('KNeighborsClassifier', KNN.predict(X_test_stand)))

# %%
predict.append(('LogisticRegression', LR.predict(X_test_stand)))

# %%
predict.append(('GaussianNB', NB.predict(X_test)))

# %%
predict.append(('AdaBoostClassifier', AB.predict(X_test)))

# %%
predict
# Out:
# [('DecisionTreeClassifier', array([1, 1, 1, ..., 1, 1, 1], dtype=int64)),
#  ('RandomForestClassifier', array([1, 1, 1, ..., 1, 1, 1], dtype=int64)),
#  ('KNeighborsClassifier', array([1, 1, 1, ..., 1, 1, 1], dtype=int64)),
#  ('LogisticRegression', array([1, 1, 1, ..., 1, 1, 1], dtype=int64)),
#  ('GaussianNB', array([1, 1, 1, ..., 1, 1, 1], dtype=int64)),
#  ('AdaBoostClassifier', array([1, 1, 1, ..., 1, 1, 1], dtype=int64))]

# %%
for name, pred in predict:
    print('Accuracy score in {}:'.format(name), accuracy_score(pred, y_test))
# Out:
# Accuracy score in DecisionTreeClassifier: 0.9800267357442732
# Accuracy score in RandomForestClassifier: 0.9840663588565233
# Accuracy score in KNeighborsClassifier: 0.982446197394805
# Accuracy score in LogisticRegression: 0.8668125633356846
# Accuracy score in GaussianNB: 0.8298122029575647
# Accuracy score in AdaBoostClassifier: 0.8306469249273853

# %%
for name, pred in predict:
    cm = confusion_matrix(pred,
                      y_test,
                      normalize='true')
    plt.figure(figsize=(13,9))
    
    if accuracy_score(pred, y_test) > 0.9:
        cmap = 'Greens'
    else:
        cmap = 'Reds'
    hm = sns.heatmap(cm,
                annot=True,
                xticklabels=categories.keys(),
                yticklabels=categories.keys(),
                cmap = cmap)
    plt.title(name)
    hm.set_xlabel('Predicted label')
    hm.set_ylabel('True label')
